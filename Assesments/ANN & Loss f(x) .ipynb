# %%
import matplotlib.pyplot as plt 
from tensorflow.keras.models import Sequential 
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import SGD
import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf

# %%
(X_train, y_train),(X_test, y_test) = mnist.load_data()

# %%
# Data Preprocessing
X_train = X_train / 255.0  # Normalize to range [0, 1]
X_test = X_test / 255.0
y_train = to_categorical(y_train, 10)  # One-hot encode labels
y_test = to_categorical(y_test, 10)

# %% [markdown]
# These ANN models are run with different batch sizes to determine the accuracy between them

# %%
# Building the Model
model = Sequential([
    Flatten(input_shape=(28, 28)),   # Flatten the 28x28 images to a 1D vector
    Dense(128, activation='relu'),   # First dense layer with 128 neurons
    Dense(64, activation='relu'),    # Second dense layer with 64 neurons
    Dense(10, activation='softmax')  # Output layer with 10 neurons for 10 classes
])
# Out:
# 2024-10-15 18:51:35.555722: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Max
# 2024-10-15 18:51:35.555744: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 64.00 GB
# 2024-10-15 18:51:35.555749: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 24.00 GB
# 2024-10-15 18:51:35.555789: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-10-15 18:51:35.555801: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# Compiling the Model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Training the Model
history = model.fit(X_train, y_train, epochs=10, batch_size=8, validation_split=0.2, verbose=1)

# %%
# Evaluating the Model
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# Test Accuracy: 0.9744

# %%
# Plotting the Training History
plt.figure(figsize=(12, 4))

# Plot training & validation accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training & validation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
#ANN model 2 
model_2 = Sequential([
    Flatten(input_shape=(28, 28)), 
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# %%
#Compile Model 2 
model_2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Training the Model
history_2 = model_2.fit(X_train, y_train, epochs=10, batch_size=128, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9694 - loss: 0.1049 - val_accuracy: 0.9701 - val_loss: 0.0987
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9801 - loss: 0.0679 - val_accuracy: 0.9722 - val_loss: 0.0898
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9849 - loss: 0.0489 - val_accuracy: 0.9743 - val_loss: 0.0849
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9891 - loss: 0.0375 - val_accuracy: 0.9757 - val_loss: 0.0875
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9915 - loss: 0.0288 - val_accuracy: 0.9766 - val_loss: 0.0794
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9951 - loss: 0.0193 - val_accuracy: 0.9762 - val_loss: 0.0865
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9963 - loss: 0.0155 - val_accuracy: 0.9768 - val_loss: 0.0841
# Epoch 8/10
# ...

# %%
test_loss_2, test_accuracy_2 = model_2.evaluate(X_test, y_test, verbose=0)
print(f'Test Accuracy: {test_accuracy_2:.4f}')
# Out:
# Test Accuracy: 0.9796

# %%
# Plotting the Training History
plt.figure(figsize=(12, 4))

# Plot training & validation accuracy
plt.subplot(1, 2, 1)
plt.plot(history_2.history['accuracy'], label='Train Accuracy')
plt.plot(history_2.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model 2 Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training & validation loss
plt.subplot(1, 2, 2)
plt.plot(history_2.history['loss'], label='Train Loss')
plt.plot(history_2.history['val_loss'], label='Validation Loss')
plt.title('Model 2 Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
model_3 = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

model_3.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

batch_size = len(X_train)

# Training the Model
history_3 = model_3.fit(X_train, y_train, epochs=10, batch_size=batch_size, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1110 - loss: 2.3329 - val_accuracy: 0.2103 - val_loss: 2.2115
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.2027 - loss: 2.2190 - val_accuracy: 0.3193 - val_loss: 2.1096
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.3078 - loss: 2.1185 - val_accuracy: 0.4098 - val_loss: 2.0108
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.3942 - loss: 2.0215 - val_accuracy: 0.4900 - val_loss: 1.9100
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.4678 - loss: 1.9226 - val_accuracy: 0.5673 - val_loss: 1.8058
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.5432 - loss: 1.8207 - val_accuracy: 0.6233 - val_loss: 1.6993
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.5989 - loss: 1.7166 - val_accuracy: 0.6575 - val_loss: 1.5923
# Epoch 8/10
# ...

# %%
test_loss_3, test_accuracy_3 = model_3.evaluate(X_test, y_test, verbose=0)
print(f'Test Accuracy: {test_accuracy_3:.4f}')
# Out:
# Test Accuracy: 0.7196

# %%
# Plotting the Training History
plt.figure(figsize=(12, 4))

# Plot training & validation accuracy
plt.subplot(1, 2, 1)
plt.plot(history_3.history['accuracy'], label='Train Accuracy')
plt.plot(history_3.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model 3 Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training & validation loss
plt.subplot(1, 2, 2)
plt.plot(history_3.history['loss'], label='Train Loss')
plt.plot(history_3.history['val_loss'], label='Validation Loss')
plt.title('Model 3 Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
model_4 = Sequential([
    Flatten(input_shape=(28,28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
    
])

optimizer = SGD(learning_rate=0.01)
optimizer_2 = SGD(learning_rate=100)
optimizer_3 = SGD(learning_rate=0.0000001)

model_4.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Training the Model
history_4 = model_4.fit(X_train, y_train, epochs=10, batch_size=128, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.6606 - loss: 1.2224 - val_accuracy: 0.9008 - val_loss: 0.3461
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.9033 - loss: 0.3389 - val_accuracy: 0.9238 - val_loss: 0.2727
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9198 - loss: 0.2772 - val_accuracy: 0.9337 - val_loss: 0.2365
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9292 - loss: 0.2434 - val_accuracy: 0.9392 - val_loss: 0.2122
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9392 - loss: 0.2134 - val_accuracy: 0.9457 - val_loss: 0.1953
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9444 - loss: 0.1957 - val_accuracy: 0.9503 - val_loss: 0.1775
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9518 - loss: 0.1680 - val_accuracy: 0.9541 - val_loss: 0.1656
# Epoch 8/10
# ...

# %%
# Evaluating the Model
test_loss_4, test_accuracy_4 = model_4.evaluate(X_test, y_test, verbose=0)
print(f'Test Accuracy: {test_accuracy_4:.4f}')
# Out:
# Test Accuracy: 0.9596

# %%
# Plotting the Training History
plt.figure(figsize=(12, 4))

# Plot training & validation accuracy
plt.subplot(1, 2, 1)
plt.plot(history_4.history['accuracy'], label='Train Accuracy')
plt.plot(history_4.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model 4 Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training & validation loss
plt.subplot(1, 2, 2)
plt.plot(history_4.history['loss'], label='Train Loss')
plt.plot(history_4.history['val_loss'], label='Validation Loss')
plt.title('Model 4 Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
optimizer_2 = SGD(learning_rate= 100.00)
optimizer_3 = SGD(learning_rate= 0.0000001)

# %%
model_4.compile(optimizer=optimizer_2, loss='categorical_crossentropy', metrics=['accuracy'])

# Training the Model
history_5 = model_4.fit(X_train, y_train, epochs=10, batch_size=128, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.1167 - loss: 7714273636034543616.0000 - val_accuracy: 0.1081 - val_loss: 42.9456
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.0999 - loss: 40.7957 - val_accuracy: 0.0989 - val_loss: 31.8854
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.0994 - loss: 39.3212 - val_accuracy: 0.1081 - val_loss: 44.2816
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.0977 - loss: 40.3727 - val_accuracy: 0.1081 - val_loss: 41.2361
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.0988 - loss: 40.6101 - val_accuracy: 0.0975 - val_loss: 42.0124
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.1009 - loss: 41.5950 - val_accuracy: 0.0975 - val_loss: 34.1610
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.1014 - loss: 39.3793 - val_accuracy: 0.1060 - val_loss: 41.2069
# Epoch 8/10
# ...

# %%
test_loss_5, test_accuracy_5 = model_4.evaluate(X_test, y_test, verbose=0)
print(f'Test Accuracy: {test_accuracy_5:.4f}')
# Out:
# Test Accuracy: 0.0892

# %%
# Plotting the Training History
plt.figure(figsize=(12, 4))

# Plot training & validation accuracy
plt.subplot(1, 2, 1)
plt.plot(history_5.history['accuracy'], label='Train Accuracy')
plt.plot(history_5.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model 5 Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training & validation loss
plt.subplot(1, 2, 2)
plt.plot(history_5.history['loss'], label='Train Loss')
plt.plot(history_5.history['val_loss'], label='Validation Loss')
plt.title('Model 5 Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
model_4.compile(optimizer=optimizer_3, loss='categorical_crossentropy', metrics=['accuracy'])

# Training the Model
history_6 = model_4.fit(X_train, y_train, epochs=10, batch_size=128, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.0898 - loss: 33.3903 - val_accuracy: 0.0914 - val_loss: 33.3342
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.0900 - loss: 33.5227 - val_accuracy: 0.0914 - val_loss: 33.3342
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.0914 - loss: 33.3684 - val_accuracy: 0.0914 - val_loss: 33.3342
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.0906 - loss: 33.5075 - val_accuracy: 0.0914 - val_loss: 33.3342
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.0893 - loss: 33.6029 - val_accuracy: 0.0914 - val_loss: 33.3342
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.0899 - loss: 33.3279 - val_accuracy: 0.0914 - val_loss: 33.3342
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.0905 - loss: 33.4464 - val_accuracy: 0.0914 - val_loss: 33.3342
# Epoch 8/10
# ...

# %%
test_loss_6, test_accuracy_6 = model_4.evaluate(X_test, y_test, verbose=0)
print(f'Test Accuracy: {test_accuracy_6:.4f}')
# Out:
# Test Accuracy: 0.0892

# %%
# Plotting the Training History
plt.figure(figsize=(12, 4))

# Plot training & validation accuracy
plt.subplot(1, 2, 1)
plt.plot(history_6.history['accuracy'], label='Train Accuracy')
plt.plot(history_6.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model 6 Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training & validation loss
plt.subplot(1, 2, 2)
plt.plot(history_6.history['loss'], label='Train Loss')
plt.plot(history_6.history['val_loss'], label='Validation Loss')
plt.title('Model 6 Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()
