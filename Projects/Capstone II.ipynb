# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
raw_stats = pd.read_csv('/Users/captzam/Documents/GitHub/datasci_thinkful/csv/game.csv')

raw_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65698 entries, 0 to 65697
# Data columns (total 55 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   season_id               65698 non-null  int64
#  1   team_id_home            65698 non-null  int64
#  2   team_abbreviation_home  65698 non-null  object
#  3   team_name_home          65698 non-null  object
#  4   game_id                 65698 non-null  int64
#  5   game_date               65698 non-null  object
#  6   matchup_home            65698 non-null  object
#  7   wl_home                 65696 non-null  object
#  8   min                     65698 non-null  int64
#  9   fgm_home                65685 non-null  float64
#  10  fga_home                50251 non-null  float64
#  11  fg_pct_home             50208 non-null  float64
#  12  fg3m_home               52480 non-null  float64
#  13  fg3a_home               47015 non-null  float64
# ...

# %%
#raw_stats.head(20)

raw_stats
corr = raw_stats.corr()['pts_home'].abs().sort_values(ascending=False)

print(corr)
# Out:
# pts_home                  1.000000
# fgm_home                  0.868800
# fg_pct_home               0.680819
# ast_home                  0.623884
# pts_away                  0.597564
# fgm_away                  0.538161
# plus_minus_away           0.469148
# plus_minus_home           0.469148
# fga_away                  0.460138
# fga_home                  0.433175
# wl_away                   0.361056
# wl_home                   0.360428
# ftm_home                  0.313712
# fta_home                  0.280238
# fg3_pct_home              0.267018
# ast_away                  0.253701
# min                       0.219598
# fg3m_home                 0.217428
# dreb_away                 0.208171
# pf_away                   0.205729
# dreb_home                 0.199984
# ftm_away                  0.199794
# fta_away                  0.197753
# reb_home                  0.194241
# ft_pct_home               0.176394
# fg_pct_away               0.170951
# fg3a_home                 0.169949
# ...

# %%
from sklearn.preprocessing import LabelEncoder 
# Sample DataFrame with categorical features 
#data = { 'feature1': ['A', 'B', 'A', 'C', 'B'], 'feature2': ['X', 'Y', 'Y', 'X', 'Z'], 'target': [1, 2, 3, 4, 5] } 
#df = pd.DataFrame(data) 
# Initialize the LabelEncoder 
label_encoder = LabelEncoder() 
# Apply LabelEncoder to each categorical feature 
for column in raw_stats.select_dtypes(include=['object']).columns: 
    raw_stats[column] = label_encoder.fit_transform(raw_stats[column]) 
# Display the transformed DataFrame 
print(raw_stats)
# Out:
#        season_id  team_id_home  team_abbreviation_home  team_name_home  \
# 0          21946    1610610035                      37              87
# 1          21946    1610610034                       7              79
# 2          21946    1610610032                      72              68
# 3          21946    1610610025                      15              16
# 4          21946    1610610028                      21              24
# ...          ...           ...                     ...             ...
# 65693      42022    1610612748                      50              47
# 65694      42022    1610612748                      50              47
# 65695      42022    1610612743                      22              23
# 65696      32022    1610616834                      45              84
# 65697      32022    1610616834                      45              84
#
#         game_id  game_date  matchup_home  wl_home  min  fgm_home  ...  \
# ...

# %%
raw_stats_dummies_home_record = pd.get_dummies(raw_stats['wl_home'])

raw_stats_dummies_home_record = pd.DataFrame(raw_stats_dummies_home_record)
#raw_stats = pd.concat([raw_stats, raw_stats_dummies_home_record], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:219, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File index.pyx:227, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File index.pyx:119, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'W'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 6
# ...

# %%
raw_stats.drop(['L'], axis=1, inplace=True )

raw_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65698 entries, 0 to 65697
# Data columns (total 53 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   season_id               65698 non-null  int64
#  1   team_id_home            65698 non-null  int64
#  2   team_abbreviation_home  65698 non-null  object
#  3   team_name_home          65698 non-null  object
#  4   game_id                 65698 non-null  int64
#  5   game_date               65698 non-null  object
#  6   matchup_home            65698 non-null  object
#  7   wl_home                 65696 non-null  object
#  8   min                     65698 non-null  int64
#  9   fgm_home                65685 non-null  float64
#  10  fga_home                50251 non-null  float64
#  11  fg_pct_home             50208 non-null  float64
#  12  fg3m_home               52480 non-null  float64
#  13  fg3a_home               47015 non-null  float64
# ...

# %%
raw_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65698 entries, 0 to 65697
# Data columns (total 53 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   season_id               65698 non-null  int64
#  1   team_id_home            65698 non-null  int64
#  2   team_abbreviation_home  65698 non-null  object
#  3   team_name_home          65698 non-null  object
#  4   game_id                 65698 non-null  int64
#  5   game_date               65698 non-null  object
#  6   matchup_home            65698 non-null  object
#  7   wl_home                 65696 non-null  object
#  8   min                     65698 non-null  int64
#  9   fgm_home                65685 non-null  float64
#  10  fga_home                50251 non-null  float64
#  11  fg_pct_home             50208 non-null  float64
#  12  fg3m_home               52480 non-null  float64
#  13  fg3a_home               47015 non-null  float64
# ...
